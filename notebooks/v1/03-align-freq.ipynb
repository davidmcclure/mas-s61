# %%
import numpy as np
import pandas as pd

from scipy.spatial.distance import cosine
from gensim.models import Word2Vec

# %%
pd.options.display.max_rows = 1000

# %%
ne = Word2Vec.load('../data/northeast.bin')

# %%
mw = Word2Vec.load('../data/midwest.bin')

# %%
ne_vocab = set([k for k, v in ne.wv.vocab.items() if v.count > 10000])

# %%
mw_vocab = set([k for k, v in mw.wv.vocab.items() if v.count > 10000])

# %%
vocab = set.intersection(ne_vocab, mw_vocab)

# %%
vocab = sorted(vocab)

# %%
len(vocab)
# Out:
# 4346

# %%
ne_m = np.stack([ne[t] for t in vocab])

# %%
mw_m = np.stack([mw[t] for t in vocab])

# %%
ne_m.shape
# Out:
# (4346, 200)

# %%
mw_m.shape
# Out:
# (4346, 200)

# %%
basevecs = ne_m - ne_m.mean(0)

# %%
othervecs = mw_m - mw_m.mean(0)

# %%
m = othervecs.T.dot(basevecs)

# %%
u, _, v = np.linalg.svd(m)

# %%
ortho = u.dot(v)

# %%
fixedvecs = othervecs.dot(ortho)

# %%
data = []
for i, token in enumerate(vocab):
    d = cosine(ne_m[i], fixedvecs[i])
    data.append((token, d))

# %%
df = pd.DataFrame(data, columns=('token', 'distance'))

# %%
df.sort_values('distance', ascending=False).head(200)
# Out:
#                token  distance
# 38     #kcapinoystar  0.809416
# 1129              cr  0.772725
# 1157              ct  0.559044
# 90            #truth  0.554499
# 4226              wi  0.548607
# 2469              ma  0.543152
# 2448           louis  0.518994
# 2612              mo  0.468071
# 18             #etsy  0.454011
# 2850              pa  0.439254
# 2571              mi  0.437136
# 111             0mph  0.417355
# 6                #__  0.416115
# 5                 #_  0.413496
# 2611              mm  0.409922
# 1406         eastern  0.408969
# 70               #rt  0.403232
# 40           #listen  0.394094
# 2695              ne  0.393697
# 2209         johnson  0.393134
# 95          #weather  0.384889
# 3784           swift  0.384687
# 460              ann  0.384441
# 42             #love  0.382867
# 2317        lawrence  0.379290
# 614             baro  0.379074
# 1616              fi  0.375426
# 2038             hum  0.366923
# 2390         lincoln  0.366060
# 2896            paul  0.365292
# 238               91  0.362091
# 362          address  0.359258
# 41       #listenlive  0.358719
# 21               #ff  0.356863
# 3362           saint  0.353745
# 754              bow  0.352735
# 7               #___  0.351260
# 3842            temp  0.348821
# 4259            wolf  0.348780
# 27         #handmade  0.347589
# 3781           swamp  0.344055
# 1538         express  0.338322
# 4027            twin  0.337242
# 1392          eagles  0.335562
# 2438             los  0.333954
# 3297            rico  0.330898
# 1968           hills  0.327219
# 1511              ew  0.324422
# 2764              ny  0.323307
# 30           #hiphop  0.322278
# 493         appeared  0.321519
# 745           boston  0.321478
# 2096        incident  0.320392
# 730             bone  0.317779
# 10          #android  0.317674
# 1825          gospel  0.315134
# 3738              su  0.313481
# 800          buffalo  0.313330
# 1901           harry  0.313107
# 3983          travis  0.313050
# 3818          taylor  0.312147
# 4181          wealth  0.311047
# 2366              li  0.310832
# 3333            ross  0.310422
# 639            bears  0.308651
# 3622        southern  0.307349
# 82             #tcot  0.302446
# 1269             dew  0.301795
# 623             bass  0.300391
# 2918           perry  0.298036
# 1966            hill  0.294831
# 1983              ho  0.293726
# 241               95  0.291980
# 2188             jay  0.290927
# 4033              tx  0.289305
# 1837          graham  0.289165
# 2245           keith  0.288988
# 3684          steady  0.288799
# 920          charles  0.287950
# 3369             san  0.286132
# 92    #veranomtv2017  0.285604
# 2743           north  0.284852
# 630              bay  0.284604
# 3326             ron  0.284033
# 2269           kings  0.283840
# 3415             sec  0.281295
# 52             #news  0.280692
# 3111              pt  0.279169
# 1341             dot  0.278355
# 3780              sw  0.278083
# 938          chicago  0.276804
# 2633          morgan  0.276427
# 2177         jackson  0.276204
# 20          #fashion  0.274307
# 157              29m  0.271106
# 3092           promo  0.270585
# 2576        michigan  0.268233
# 4078           urban  0.267496
# 2354             les  0.267264
# 976          cleared  0.264866
# 4150          wallet  0.264613
# 2235          justin  0.263990
# 3114          puerto  0.263835
# 894          central  0.262288
# 1710        franklin  0.261641
# 3973           train  0.261252
# 2202           jimmy  0.259653
# 3296            rick  0.258872
# 2887           patch  0.258795
# 1461          engine  0.258328
# 978        cleveland  0.258036
# 222               78  0.257559
# 228               84  0.257274
# 1526            exit  0.256438
# 3113       published  0.256256
# 796            bucks  0.255902
# 4140              wa  0.255492
# 3339           royal  0.255092
# 473          anthony  0.254994
# 2240           katie  0.253519
# 2755      nowplaying  0.253301
# 691            bills  0.252198
# 49            #music  0.251930
# 1232             del  0.250441
# 2264             kim  0.250136
# 2171              iv  0.249754
# 449         anderson  0.249645
# 2793            ohio  0.249440
# 4221            whoa  0.248535
# 1544               f  0.248100
# 3340              rt  0.247975
# 2464             luv  0.247844
# 4326           yikes  0.247785
# 2514            mass  0.246950
# 3922             tim  0.246473
# 1188           danny  0.246162
# 450           andrew  0.245986
# 59      #photography  0.243766
# 85          #traffic  0.243758
# 1383            duke  0.243619
# 3174             ray  0.243616
# 4094          valley  0.243477
# 4343               z  0.243266
# 2304             las  0.243174
# 615        barometer  0.242701
# 724              bob  0.242693
# 1763            gary  0.242621
# 4048             una  0.242336
# 791            bruce  0.242302
# 2323              le  0.241163
# 666             bell  0.240635
# 242               96  0.240497
# 46       #motivation  0.239978
# 1135           cream  0.239915
# 2459              lt  0.239688
# 885               cc  0.236600
# 994            cloud  0.236582
# 2196          jersey  0.236288
# 55               #np  0.235222
# 692            billy  0.234420
# 991          closing  0.233912
# 33     #iheartawards  0.233032
# 1153            cruz  0.231009
# 3004             por  0.230390
# 67           #repost  0.230133
# 2194        jennifer  0.229522
# 2950          pinned  0.229235
# 922            chart  0.228706
# 3692           steve  0.227914
# 4206         western  0.227732
# 2641           mount  0.227721
# 3621           south  0.227519
# 4176           wayne  0.227069
# 2303           larry  0.226117
# 1749              ga  0.225841
# 752            bound  0.225733
# 2423           logan  0.225656
# 959            chuck  0.225528
# 240               93  0.225508
# 1885        hamilton  0.224108
# 1035            como  0.224101
# 407              aku  0.224024
# 3969         trading  0.223673
# 2156          island  0.223348
# 3737          styles  0.223336
# 3893          thomas  0.223188
# 2207            john  0.223007
# 22          #fitness  0.222118
# 319                _  0.221962
# 4270           woods  0.221612
# 4100           vegas  0.221319
# 375         advisory  0.220870
# 2298            lang  0.220762
# 1007             cod  0.220499
# 116              101  0.220322
# 4064         unknown  0.220293
# 2929            phil  0.219703
# 589               ba  0.219662
# 4074           upper  0.219605
# 3658              st  0.219349

# %%
def compare(token):
    for t, _ in ne.most_similar(token, topn=20):
        print(t)
    print('\n')
    for t, _ in mw.most_similar(token, topn=20):
        print(t)

# %%
compare('bone')
# Out:
# bones
# bruise
# tissue
# wrist
# arm
# chest
# bruised
# claw
# neck
# skull
# flesh
# ribs
# hammer
# mold
# elbow
# knee
# lump
# groin
# chin
# thumb
#
#
# bones
# knuckles
# wrist
# neck
# gums
# tooth
# claws
# chest
# elbow
# joints
# bun
# claw
# rag
# bruised
# meat
# cheek
# bruise
# strain
# vein
# sock
