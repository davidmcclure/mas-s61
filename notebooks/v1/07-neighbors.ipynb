# %%
import numpy as np
import pandas as pd

from scipy.spatial.distance import cosine
from gensim.models import Word2Vec
from itertools import combinations
from tqdm import tqdm_notebook

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
pd.options.display.max_rows = 1000

# %%
m1 = Word2Vec.load('../data/northeast.bin')

# %%
m2 = Word2Vec.load('../data/south.bin')

# %%
m1_vocab = set(m1.wv.vocab.keys())

# %%
m2_vocab = set(m2.wv.vocab.keys())

# %%
vocab = set.intersection(m1_vocab, m2_vocab)

# %%
m1.most_similar('future', topn=30)
# Out:
# [('#future', 0.4707292914390564),
#  ('environment', 0.4664434790611267),
#  ('vision', 0.4526408910751343),
#  ('disruption', 0.4488123059272766),
#  ('workforce', 0.4360583424568176),
#  ('evolution', 0.42711004614830017),
#  ('demise', 0.42570436000823975),
#  ('importance', 0.4196147322654724),
#  ('current', 0.41241762042045593),
#  ('#ai', 0.4077520966529846),
#  ('ecosystem', 0.4015895128250122),
#  ('world', 0.3986409604549408),
#  ('innovation', 0.3985614776611328),
#  ('industry', 0.397148072719574),
#  ('workplace', 0.3926817774772644),
#  ('growth', 0.3883310854434967),
#  ('downfall', 0.3877112865447998),
#  ('success', 0.3876093029975891),
#  ('apocalypse', 0.38388705253601074),
#  ('retirement', 0.38374513387680054),
#  ('economy', 0.38292959332466125),
#  ('classroom', 0.38266217708587646),
#  ('futures', 0.38233011960983276),
#  ('uncertainty', 0.38059288263320923),
#  ('outcomes', 0.38049864768981934),
#  ('generation', 0.3804638385772705),
#  ('capabilities', 0.37959936261177063),
#  ('expertise', 0.37851113080978394),
#  ('role', 0.3779846429824829),
#  ('#ar', 0.3770034611225128)]

# %%
m2.most_similar('future', topn=30)
# Out:
# [('#future', 0.5354784727096558),
#  ('environment', 0.4608862102031708),
#  ('futures', 0.4495675563812256),
#  ('workforce', 0.4236217439174652),
#  ('importance', 0.4124824106693268),
#  ('demise', 0.4087694585323334),
#  ('vision', 0.4072023034095764),
#  ('world', 0.40298983454704285),
#  ('retirement', 0.39981478452682495),
#  ('evolution', 0.39876511693000793),
#  ('classroom', 0.38804003596305847),
#  ('life', 0.38655632734298706),
#  ('roadmap', 0.38359570503234863),
#  ('disruption', 0.3824882507324219),
#  ('finances', 0.38226318359375),
#  ('greatness', 0.38131940364837646),
#  ('profession', 0.38119643926620483),
#  ('outcome', 0.3795522451400757),
#  ('workplace', 0.37652039527893066),
#  ('current', 0.3761433959007263),
#  ('universe', 0.373193621635437),
#  ('growth', 0.37295275926589966),
#  ('success', 0.37078121304512024),
#  ('role', 0.36806827783584595),
#  ('afterlife', 0.36779117584228516),
#  ('#infrastructure', 0.3662795126438141),
#  ('economy', 0.36561623215675354),
#  ('blockchain', 0.3650515675544739),
#  ('#ai', 0.36501529812812805),
#  ('#artificialintelligence', 0.3646790087223053)]

# %%
def neighbors_similarity(m1, m2, token, topn=20):
    
    m1n = [t for t, _ in m1.most_similar(token, topn=topn)]
    m2n = [t for t, _ in m2.most_similar(token, topn=topn)]
    
    sim = 0
    for t1, t2 in [(t1, t2) for t1 in m1n for t2 in m2n]:
        if t1 in m1 and t2 in m1:
            sim += m1.similarity(t1, t2)
            
    return sim

# %%
# %time neighbors_similarity(m1, m2, 'universe')
# Out:
# CPU times: user 17.9 ms, sys: 1.38 ms, total: 19.2 ms
# Wall time: 10.2 ms
# 119.76173110848821

# %%
data = []
for v in tqdm_notebook(vocab):
        count = m1.wv.vocab[v].count + m2.wv.vocab[v].count
        score = neighbors_similarity(m1, m2, v)
        data.append((v, count, score))
# Out:
# HBox(children=(IntProgress(value=0, max=22318), HTML(value='')))

# %%
df = pd.DataFrame(data, columns=('word', 'count', 'score'))

# %%
len(df)
# Out:
# 22318

# %%
df[df['count'] > 1e5].sort_values('score', ascending=True).head(100)
# Out:
#                  word     count      score
# 22135              ma    266797  -8.569516
# 13150     #listenlive    281483   8.775800
# 13184              rt   1243817  11.718835
# 17542         unknown    249996  18.058784
# 3017             unkn    109925  22.155887
# 11326         #hiring    961144  26.575404
# 11315          austin    128336  27.305741
# 12967   automatically    710859  32.383027
# 13351              gt   5947379  32.855070
# 18830   #mplusrewards    112845  33.684681
# 11113              la    768131  35.096045
# 5721               un    278662  35.665560
# 16072             til    208271  39.411393
# 10946            gone    465191  41.773852
# 1129              now   4506419  42.802204
# 643            single    387902  44.210149
# 20443            main    129381  46.297818
# 14367              lt   2532423  47.846102
# 21071              cp    117595  48.208553
# 6645             here   2943780  48.843960
# 8451          houston    239541  50.918627
# 8780           dallas    162859  52.560352
# 715                by   5849571  52.724136
# 7574          earning    140137  53.424300
# 20796          jersey    137372  53.559474
# 22057          disney    112495  55.495761
# 17640              ga    176550  55.581735
# 20886             com    240766  56.756883
# 22070         forever    283344  57.224560
# 9922             wire    209239  57.476600
# 3326   #newprofilepic    193891  59.497552
# 6279         followed    670563  59.685201
# 3500            cross    102391  59.752342
# 7909              con    226335  59.816266
# 5076               an   3202167  60.533977
# 6147                #    429177  60.906269
# 18628            holy    208804  61.133355
# 7074       nowplaying    109809  61.285892
# 20538            rare    105949  61.660272
# 7974              fit    329393  61.759006
# 18938            bank    120114  62.047670
# 14405            spot    186040  62.390954
# 14242              at   8958591  62.408946
# 21551            race    177777  62.857118
# 10081            near    200294  63.022117
# 11247         opening    417482  63.196970
# 21930            view    265447  63.539904
# 12042             san    140918  64.428912
# 10854           magic    109955  64.441953
# 13308              al    229487  64.539771
# 16152             29m    108451  64.588988
# 1290            #love    114661  65.051234
# 3183              amp   6034653  65.274034
# 19258              mo    137088  65.302930
# 17589             our   3277935  65.976527
# 7318               te    188182  67.107407
# 12141       challenge    155094  67.676843
# 12685             the  46950933  67.817446
# 12743               q    169770  68.499865
# 10127            #nfl    109178  69.488996
# 18176             gun    134746  69.876675
# 15111          middle    202555  70.138721
# 2489            short    234430  70.315844
# 7801      #nowplaying   1042743  70.481610
# 14012            than   1658697  70.593853
# 19335      interested    230370  70.746670
# 14299           until    959891  71.946995
# 4306         straight    259734  72.196957
# 412                mi    216005  72.907711
# 16963             luv    108909  73.346152
# 16418               f    536715  73.891930
# 20942            pero    103367  74.354066
# 5433          checked    908788  74.587422
# 13448           click    540830  74.806542
# 15834        pressure    128670  75.744361
# 305              tune    189169  75.886089
# 11819               _    334285  75.988373
# 9084             born    133358  76.095078
# 6483              air    299643  76.209131
# 10680     #realestate    107417  76.421565
# 21419             key    205891  76.534792
# 5251          forward    277639  76.625145
# 20568            this  14698041  76.785370
# 7376               eu    125361  77.094749
# 2143             date    260071  77.253029
# 15645              da    322750  77.507275
# 19472            full    541211  77.577977
# 21251            from   5089313  77.586339
# 6079         surprise    133424  77.601988
# 12454              um    125374  77.832730
# 2744               fl    245523  78.140000
# 9537             past    357044  78.147199
# 3672              new   4207796  78.362693
# 12669      especially    213717  78.870880
# 10239              of  19460298  79.077950
# 20234            deep    218920  79.139340
# 7467             hell    581619  79.313094
# 6911                a  33965048  79.387438
# 12235       currently    142652  79.390117
# 11422           close    327676  79.747136

# %%
def compare(token):
    for t, _ in m1.most_similar(token, topn=20):
        print(t)
    print('\n')
    for t, _ in m2.most_similar(token, topn=20):
        print(t)

# %%
compare('bank')
# Out:
# banks
# banking
# savings
# bankers
# debit
# deposit
# corporate
# pension
# mall
# union
# pnc
# capital
# pharmaceutical
# atm
# account
# walgreens
# loan
# merchant
# postal
# investments
#
#
# banks
# banking
# securities
# debit
# savings
# jpmorgan
# treasury
# deposits
# bankers
# corp
# amex
# payable
# coinbase
# account
# brokerage
# lender
# @paypal
# deposit
# union
# mastercard

# %%
plt.scatter(df['count'], df['score'])
