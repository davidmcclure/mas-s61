# %%
import numpy as np
import pandas as pd

from scipy.spatial.distance import cosine
from gensim.models import Word2Vec

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
pd.options.display.max_rows = 1000

# %%
m1 = Word2Vec.load('../data/northeast.bin')

# %%
m2 = Word2Vec.load('../data/south.bin')

# %%
m1_vocab = set(m1.wv.vocab.keys())

# %%
m2_vocab = set(m2.wv.vocab.keys())

# %%
vocab = set.intersection(m1_vocab, m2_vocab)

# %%
vocab = sorted(vocab)

# %%
m1_m = np.stack([m1[t] for t in vocab])

# %%
m2_m = np.stack([m2[t] for t in vocab])

# %%
basevecs = m1_m - m1_m.mean(0)

# %%
othervecs = m2_m - m2_m.mean(0)

# %%
m = othervecs.T.dot(basevecs)

# %%
u, _, v = np.linalg.svd(m)

# %%
ortho = u.dot(v)

# %%
m2f = othervecs.dot(ortho)

# %%
data = []
for i, token in enumerate(vocab):
    c = m1.wv.vocab[token].count + m2.wv.vocab[token].count
    d = cosine(m1_m[i], m2f[i])
    data.append((token, c, d))

# %%
df = pd.DataFrame(data, columns=('token', 'count', 'distance'))

# %%
len(df[df['count'] > 1e4])
# Out:
# 10988

# %%
df[df['count'] > 1e4].sort_values('distance', ascending=False).head(200)
# Out:
#                     token   count  distance
# 10137           fornadine   13651  1.036916
# 401                #dream   20404  0.946814
# 1445          #taptapfish   31251  0.840285
# 1071         #opportunity   31156  0.835714
# 1136          #playingnow   15968  0.820826
# 678                 #hope   23803  0.772987
# 1525              #trecru   27071  0.763743
# 4531               approx   19749  0.763241
# 990                   #nc   23584  0.750650
# 791         #kcapinoystar   77227  0.748854
# 467                  #f4f   10260  0.743851
# 9624              fairfax   11568  0.738658
# 18034             satchel   48500  0.734801
# 1032                 #now   34809  0.730210
# 12634                katy   54607  0.728626
# 5437           blackberry   16255  0.704303
# 15195                  oo   60583  0.703397
# 901                   #me   11813  0.702442
# 1553                  #tx   54373  0.698601
# 8233               detour   10324  0.687146
# 7632            crossbody   76115  0.685439
# 1526            #trending   11740  0.684853
# 8459             dispatch   70500  0.679168
# 977         #nadinelustre   75140  0.670534
# 21536                  vt   17244  0.668372
# 10219           frederick   13349  0.666935
# 518                   #fl   53761  0.665281
# 1083                  #pa   12765  0.647017
# 13546                  ma  266797  0.639009
# 1049             #nytimes   14739  0.633130
# 8264             dewpoint   16049  0.631769
# 1638        #workfromhome   12185  0.631679
# 16862                  ra   32731  0.631008
# 19310                 sta   10573  0.630843
# 168                 #best   17767  0.629864
# 11588              hourly   13816  0.623532
# 17573                  ri   32265  0.617103
# 14439                  mp   17661  0.614565
# 11051             handbag   91957  0.612471
# 1546              #tunein   27474  0.608041
# 8592                 dome   27686  0.608003
# 1165      #premiosmtvmiaw   41870  0.604797
# 19574              stripe   27519  0.599820
# 1580           #videolove   10686  0.595659
# 5117                baton   12335  0.592995
# 7510                   cr   25349  0.592194
# 4442              antonio   62601  0.585491
# 1569                  #va   14452  0.582388
# 11718                 ian   33067  0.580369
# 6872                 cobb   11685  0.462428
# 9479                  exp   27168  0.462318
# 7763           customized   16312  0.461767
# 10043              flyers   17537  0.460306
# 12088       instrumentals   10053  0.460270
# 12478               johns   14101  0.459782
# 5722                   bp   16160  0.459303
# 13140                 lex   11701  0.458630
# 843                 #like   11685  0.458498
# 685              #houston   84842  0.457694
# 20930                  tx  315521  0.457668
# 1950                  215   10289  0.457010
# 44                    #__   50661  0.456323
# 17673                  ro   14321  0.455870
# 7704               cuenta   10611  0.455609
# 9983                fleet   16477  0.455313
# 124              #atlanta   63333  0.455181
# 13373               login   21998  0.454940
# 5294              bernard   10897  0.454756
# 10194           francisco   23720  0.453233
# 269            #christian   13881  0.451194
# 1100               #peace   27702  0.450065
# 16748               purse   91947  0.448970
# 12010                inhg   16329  0.446590
# 6748            classical   11412  0.445288
# 1375               #sport   14301  0.444116
# 14755              newton   14308  0.442538
# 1534          #trumptrain   14467  0.442477
# 45                   #___   43497  0.441439
# 17540             revival   15938  0.440585
# 582                #gifts   10709  0.438970
# 15219           operating   18062  0.438940
# 205               #boston   55689  0.437292
# 5494                  blk   19665  0.437253
# 6499            charlotte   70239  0.435166
# 566                #games   43897  0.434946
# 14253                 mls   27396  0.434808
# 2083                  404   23296  0.433976
# 443        #entertainment   10085  0.433954
# 21486                vivo   13217  0.432959
# 1513                #toys   11521  0.432327
# 11958              indoor   55788  0.432223
# 6577                  chi   19865  0.432159
# 8311                diego   25315  0.431580
# 2284                  911   95681  0.431091
# 43                     #_   87307  0.430456
# 150           #basketball   13510  0.429835
# 1267                  #rt   88347  0.428223
# 6902                 cola   11444  0.428051
# 15863              phanpy   10016  0.427905
# 1202               #radio   49853  0.427129
# 19528              straps   11833  0.426992
# 769                 #jazz   10288  0.426871
# 321              #cowboys   17937  0.426840
# 5076               barrel   29778  0.426408
# 455         #etsychaching   11011  0.424866
# 20464                  tm   13676  0.423726
# 18139                 sci   18770  0.423153
# 1582        #videomtv2016   20630  0.422456
# 18236                 sec   66429  0.422367
# 1393            #steelers   19220  0.421951
# 10077                 foo   15126  0.421882
# 215         #breakingnews   17670  0.421830
# 14788                nico   10105  0.421007
# 765               #itunes   29083  0.420171
# 4159                   ak   22785  0.419971

# %%
def compare(token):
    for t, _ in m1.most_similar(token, topn=20):
        print(t)
    print('\n')
    for t, _ in m2.most_similar(token, topn=20):
        print(t)

# %%
compare('beach')
# Out:
# boardwalk
# lake
# #beach
# beaches
# bahamas
# wildwood
# shore
# seaside
# marina
# cove
# mall
# carnival
# pond
# nantucket
# boat
# venice
# pool
# hamptons
# waterfront
# inn
#
#
# boardwalk
# beaches
# destin
# pier
# bahamas
# riverwalk
# lake
# dunes
# oceanfront
# cove
# #beach
# inlet
# seaside
# island
# #lovefl
# shores
# marina
# springs
# cay
# poolside

# %%
plt.figure(figsize=(10, 10))
plt.xscale('log')
plt.scatter(df['count'], df['distance'], s=0.2)
