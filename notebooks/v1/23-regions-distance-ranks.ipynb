# %%
import numpy as np
import pandas as pd

from gensim.models import KeyedVectors
from scipy.spatial.distance import cosine
from tqdm import tqdm_notebook

from sources import parse_glove_vocab

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
pd.options.display.max_rows = 1000

# %%
m1 = KeyedVectors.load_word2vec_format('../data/corpora/regions/northeast.w2v.txt')

# %%
m2 = KeyedVectors.load_word2vec_format('../data/corpora/regions/south.w2v.txt')

# %%
combined = KeyedVectors.load_word2vec_format('../data/corpora/regions/combined.w2v.txt')

# %%
v1 = parse_glove_vocab('../data/corpora/regions/northeast.vocab.txt')

# %%
v2 = parse_glove_vocab('../data/corpora/regions/south.vocab.txt')

# %%
v1_total = sum(v1.values())

# %%
v2_total = sum(v2.values())

# %%
vocab = parse_glove_vocab('../data/corpora/regions/vocab.txt')

# %%
def neighbor_sim(token, topn=50):
    g1 = [t for t, _ in m1.most_similar(token, topn=topn)]
    g2 = [t for t, _ in m2.most_similar(token, topn=topn)]
    return combined.n_similarity(g1, g2)

# %%
neighbor_sim('earth')
# Out:
# 0.91948654128971818

# %%
data = []
for token in tqdm_notebook(vocab.keys()):
    
    score = neighbor_sim(token)
    
    c1 = v1[token] / v1_total
    c2 = v2[token] / v2_total

    cr = min([c1, c2]) / max([c1, c2])
    
    data.append((token, vocab[token], v1[token], v2[token], cr, score))
# Out:
# HBox(children=(IntProgress(value=0, max=8678), HTML(value='')))

# %%
df = pd.DataFrame(data, columns=('token', 'total_count', 'count1', 'count1', 'count_ratio', 'score'))

# %%
df[(df['count_ratio'] > 0.8) & (df['total_count'] > 1e5)].sort_values('score').head(100)
# Out:
#            token  total_count   count1    count1  count_ratio     score
# 1720       moves       200523    27254     84708     0.834177 -0.040034
# 1757        form       194210    32344     73442     0.875787  0.041535
# 1707     address       203140    28342     84491     0.869706  0.271660
# 2748      status       118401    17337     47289     0.950530  0.421166
# 3011         sec       105804    17435     49084     0.920946  0.423531
# 2262        draw       146999    20372     57199     0.923416  0.425680
# 2265    struggle       146856    20027     59920     0.866555  0.428866
# 318         left      1253938   201198    485595     0.930890  0.449963
# 2935        wrap       109052    14340     46233     0.804173  0.463548
# 2569        iron       128185    16279     52618     0.802132  0.479837
# 586         side       634419    96270    240092     0.961910  0.508156
# 761           co       494651    55948    180859     0.802041  0.509347
# 446         used       889247   132345    336163     0.979693  0.511598
# 2507       blast       132249    17674     52367     0.875043  0.524555
# 914        voice       406907    62012    157427     0.979155  0.525732
# 716         wild       524405    63224    166156     0.986548  0.543814
# 139         free      2961085   414363   1247293     0.861320  0.550138
# 1776       shots       192887    27923     80957     0.894252  0.562437
# 1803         tag       189914    26850     79766     0.872728  0.763087
# 2877          ap       111382    15131     46440     0.844749  0.764048
# 3024       shape       105297    17837     37736     0.815984  0.764485
# 1894     earlier       179829    30242     67108     0.855877  0.764503
# 6             in     38843548  6038279  14712177     0.939748  0.764711
# 422        place       952570   139897    363090     0.998956  0.764991
# 2787      memory       116624    17348     41881     0.931141  0.766276
# 1075         non       340263    53524    125846     0.906857  0.767431
# 2816      injury       114541    18288     40490     0.853944  0.768143
# 2131     contest       157755    22064     66080     0.865698  0.768893
# 1931        base       176234    28525     62969     0.851430  0.776360
# 2359     hitting       140389    21498     54544     0.978581  0.777347
# 129           am      3234737   493527   1243532     0.971838  0.781324
# 2560       beast       128756    21723     47998     0.852219  0.781541
# 2977      raised       107374    15281     41460     0.955597  0.781605
# 2665      headed       122635    16495     52661     0.812111  0.782255
# 2337       lines       142231    22760     53306     0.903341  0.783647
# 2910      riding       110051    16675     45094     0.958737  0.785477
# 3137        twin       100579    14072     35717     0.978965  0.786361
# 2604     request       126144    15890     43286     0.951763  0.786785
# 2009        crew       168627    25119     63753     0.978917  0.792652
# 3015       punch       105618    16163     40648     0.969985  0.798140
# 1583       alert       220709    31146     94184     0.857388  0.798645
# 2642      sunset       124321    16422     46906     0.907716  0.808263
# 2327       heads       142747    23167     53674     0.893598  0.808415
# 2592     quarter       126508    17285     47796     0.937627  0.809533
# 7            for     37595268  5783963  14385687     0.959297  0.811409
# 1966  everywhere       171806    25617     66740     0.995163  0.811536
# 2754       santa       118226     8503     22970     0.959762  0.812412
# 765        feels       492894    72023    192148     0.971824  0.812467
# 1136       block       318879    46590    114663     0.949245  0.813127
# 731         mine       512194    72307    209057     0.896743  0.814623
# 2183         max       153514    23915     56726     0.914870  0.815608
# 2382       balls       139319    22579     51830     0.885369  0.816410

# %%
plt.figure(figsize=(20, 10))
_ = plt.hist(df['score'], bins=100)

# %%
plt.figure(figsize=(20, 10))
plt.xscale('log')
plt.scatter(df['total_count'], df['score'], s=2)

# %%
def compare(token):
    for t, _ in m1.most_similar(token, topn=20):
        print(t)
    print('\n')
    for t, _ in m2.most_similar(token, topn=20):
        print(t)

# %%
compare('struggle')
# Out:
# struggles
# everyday
# wanting
# difficult
# constant
# struggling
# overcome
# maintaining
# finding
# maintain
# knowing
# splash
# relate
# basis
# sometimes
# understand
# often
# life
# strength
# thrive
#
#
# struggles
# bug
# confusion
# tackle
# bite
# everyday
# combat
# iv
# moves
# cp
# power
# hyper
# earthquake
# counter
# until
# overcome
# form
# zen
# sometimes
# unknown
