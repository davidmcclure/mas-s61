# %%
import numpy as np
import pandas as pd

from gensim.models import KeyedVectors
from scipy.spatial.distance import cosine
from tqdm import tqdm_notebook

from sources import parse_glove_vocab

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.style.use('bmh')

# %%
pd.options.display.max_rows = 1000

# %%
m1 = KeyedVectors.load_word2vec_format('../data/corpora/north-south/new-england.w2v.txt')

# %%
m2 = KeyedVectors.load_word2vec_format('../data/corpora/north-south/deep-south.w2v.txt')

# %%
v1 = parse_glove_vocab('../data/corpora/north-south/new-england.vocab.txt')

# %%
v2 = parse_glove_vocab('../data/corpora/north-south/deep-south.vocab.txt')

# %%
v1_total = sum(v1.values())

# %%
v2_total = sum(v2.values())

# %%
vocab = parse_glove_vocab('../data/corpora/north-south/vocab.txt')

# %%
def neighbor_sim(m1, m2, token, topn=50):
    g1 = [t for t, _ in m1.most_similar(token, topn=topn)]
    g2 = [t for t, _ in m2.most_similar(token, topn=topn)]
    return m1.n_similarity(g1, g2)

# %%
def cross_avg_neighbor_sim(m1, m2, token, *args, **kwargs):
    sim1 = neighbor_sim(m1, m2, token, *args, **kwargs)
    sim2 = neighbor_sim(m2, m1, token, *args, **kwargs)
    return np.mean([sim1, sim2])

# %%
cross_avg_neighbor_sim(m1, m2, 'marriage')
# Out:
# 0.91368834507294561

# %%
data = []
for token in tqdm_notebook(vocab.keys()):
    
    sim = cross_avg_neighbor_sim(m1, m2, token)
    
    c1 = v1[token] / v1_total
    c2 = v2[token] / v2_total

    cr = min([c1, c2]) / max([c1, c2])
    
    data.append((token, v1[token], v2[token], cr, sim))
# Out:
# HBox(children=(IntProgress(value=0, max=8104), HTML(value='')))

# %%
df = pd.DataFrame(data, columns=('token', 'c1', 'c2', 'cr', 'score'))

# %%
df[df['cr'] > 0.9].sort_values('score').head(200)
# Out:
#               token       c1       c2        cr     score
# 4244       stopping     3190     3822  0.909500 -0.123047
# 1820            sec     9022    11032  0.928226  0.152985
# 507          future    35620    43960  0.936842  0.251486
# 1444           heat    11029    15489  0.938016  0.266936
# 2383          labor     6305     8387  0.990321  0.287203
# 6827         labels     1520     2078  0.963597  0.338213
# 3335           spin     4036     5686  0.935065  0.344450
# 786             act    22155    28722  0.984114  0.359153
# 2975           flat     4678     6600  0.933714  0.387687
# 1691         period     9011    13044  0.910038  0.398113
# 2611        records     5945     7220  0.921908  0.399238
# 6847     earthquake     1461     2119  0.908274  0.423529
# 2788           flip     5059     7139  0.933523  0.438926
# 7912           void     1114     1605  0.914340  0.439472
# 4695            cow     2573     3508  0.966224  0.473965
# 52              now   385685   474416  0.933747  0.485322
# 3757          inner     3521     4770  0.972401  0.486675
# 2765          blast     5252     7025  0.984863  0.508932
# 4420    significant     2801     3856  0.956916  0.509440
# 5163        watches     2297     3091  0.978948  0.512803
# 1973       bringing     8195    10072  0.932973  0.513161
# 5859         heated     1925     2580  0.982898  0.518025
# 2079     everywhere     7625     9795  0.975140  0.525432
# 35              amp   487149   684438  0.937616  0.528298
# 2550          ghost     5758     7809  0.971346  0.751291
# 6541      chemistry     1714     2115  0.936703  0.752863
# 8076          betty     1037     1452  0.940827  0.753644
# 5139      charlotte     2221     3203  0.913459  0.753866
# 3645      celebrity     3716     5000  0.979046  0.755106
# 4731       extended     2710     3298  0.923812  0.755400
# 8052        warrant     1121     1430  0.968351  0.755569
# 3076           flow     4583     6222  0.970325  0.755659
# 6767           dual     1618     2037  0.955685  0.755880
# 2258        strange     6789     8983  0.995593  0.757998
# 2329        partner     6796     8357  0.933468  0.758662
# 927           works    19478    23434  0.913281  0.758920
# 2668        smoking     5569     7239  0.986742  0.760315
# 5703          rides     2015     2691  0.986413  0.760590
# 4076          kings     3367     4092  0.922561  0.760745
# 3276         legacy     4447     5502  0.939195  0.761456
# 6227        belongs     1820     2288  0.954305  0.762885
# 4846     appearance     2658     3179  0.907900  0.762944
# 5843             ch     1929     2600  0.977364  0.763180
# 7168        inmates     1436     1879  0.993287  0.764487
# 7830        elegant     1211     1591  0.997306  0.765611
# 5918         chosen     1809     2636  0.904046  0.765934
# 144            year   131543   167419  0.966139  0.766221
# 8080           hers     1017     1462  0.916371  0.766377
# 3351          twins     4055     5617  0.951008  0.767002
# 2916           dare     5221     6321  0.919040  0.767808
# 2399           wave     6102     8482  0.947701  0.767809
# 4130          urban     3243     4062  0.950814  0.769226
# 5530             nd     1995     2910  0.903124  0.770219
# 4874        furious     2615     3176  0.921958  0.773194
# 4035          sneak     3357     4190  0.947469  0.773290
# 6085          alpha     1823     2433  0.987057  0.773451
# 2953            ups     5036     6319  0.952500  0.773665
# 3803        madness     3463     4693  0.972074  0.773768
# 3304        advance     4459     5379  0.915728  0.773881
# 4059          banks     3279     4218  0.976490  0.773996
# 7661         afghan     1330     1624  0.926908  0.774048
# 4797   appreciation     2550     3372  0.996208  0.774209
# 7655            irs     1327     1632  0.933580  0.774277
# 4051            mic     3297     4219  0.971389  0.774576
# 102            only   178000   237066  0.989118  0.774598
# 1640          touch    10142    12838  0.960896  0.775870
# 7967     complaints     1200     1457  0.921681  0.776024
# 3994      childhood     3429     4210  0.932003  0.776232
# 4061           pays     3334     4160  0.947175  0.776297
# 3582           twin     3884     5049  0.986799  0.776449
# 6459          temps     1596     2305  0.912136  0.778173
# 2000          grand     7798    10183  0.991277  0.779390
# 4126      lightning     3228     4100  0.964168  0.779738
# 6093         temple     1941     2309  0.903027  0.779992
# 3723         silent     3783     4652  0.933482  0.780084
# 7923        contain     1182     1525  0.979388  0.780310
# 7017       floating     1450     1986  0.961803  0.780707
# 7627       packages     1234     1743  0.932643  0.781171
# 7034          pause     1489     1936  0.986991  0.781181
# 8046         spends     1170     1394  0.904439  0.781208

# %%
plt.figure(figsize=(20, 10))
_ = plt.hist(df['score'], bins=100)

# %%
plt.figure(figsize=(20, 10))
plt.xscale('log')
plt.scatter(df['count'], df['score'], s=2)
